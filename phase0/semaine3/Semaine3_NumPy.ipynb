# %%
import numpy as np

# Mesures biologiques de 10 patients fictifs
glycemie    = np.array([4.9, 5.2, 7.8, 6.3, 8.1, 4.7, 5.9, 7.2, 4.5, 12.4])  # mmol/L
tension_sys = np.array([118, 120, 145, 132, 158, 110, 128, 142, 115, 180])   # mmHg
age         = np.array([31, 45, 62, 55, 70, 28, 48, 67, 35, 74])             # ans

# %%
# 1. Statistiques descriptives compètes
def statistiques(mesures, nom):
    """
    Affiche moyenne, écart-type, médiane, min et max.
    :param mesures: Array Numpy
    :param nom: Nom de la mesure (str)
    :return:
    """
    pass

# 2. Détecter les valeurs aberrantes (outliers)
# Méthode : toute valeur > moyenne + 2*écart-type est aberrante
def detecter_outliers(mesures, nom):
    """
    Retourne les indices et valeurs aberrantes.
    :param mesures:  Array NumPy
    :param nom: Nom de la mesure (str)
    :return: array des valeurs aberrantes
    """
    pass

# 3. Normaliser entre 0 et 1 (min-max scaling)
def normaliser(mesures):
    """
    Normalise un array entre 0 et 1.
    :param mesures: Array NumPy
    :return: Array normalisé
    """
    pass

# 4. Corrélation entre deux mesures
def correlation(masures_a, mesures_b, nom_a, nom_b):
    """
    Affiche le coefficient de corrélation de Pearson.
    :param masures_a: Array NumPy
    :param mesures_b: Array NumPy
    :param nom_a:
    :param nom_b:
    :return:
    """
    pass
'''

Le résultat attendu ressemblera à :

=== Glycémie (mmol/L) ===
Moyenne   : 6.70
Écart-type: 2.31
Médiane   : 6.10
Min / Max : 4.50 / 12.40

Outliers glycémie : [12.4]  ← valeur suspecte détectée

=== Tension systolique (mmHg) ===
...

Corrélation âge / glycémie : 0.84  ← forte corrélation positive '''
